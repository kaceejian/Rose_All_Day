# %%
# Rosé All Day
----

#### Note
*
# Out:
#   File "<ipython-input-1-3c42b32b8931>", line 2
#     ----
#         ^
# SyntaxError: invalid syntax

# %%
import json
import requests
import pandas as pd
from config import api_key
from pandas import DataFrame

# %%
# Save config information
base_url = "https://api.wine-searcher.com/a?"
wine_name = "duckhorn+vineyards+napa+merlot"
format_ = "J"
location = "USA"

parameters = {
    'api_key': api_key,
    'winename': wine_name,
    'vintage': vintages,
    'format': format_,
    'location': location
}


vintages = [2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000]

output = []

for vintage in vintages:

    result = requests.get(url=base_url, params=parameters).json()
    
output.append(result)
    
ouput[0]

# output_dataframe = pd.DataFrame(output)
# output_dataframe.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a472dacb952b> in <module>
#      24 output.append(result)
#      25
# ---> 26 ouput[0]
#      27
#      28 # output_dataframe = pd.DataFrame(output)
#
# NameError: name 'ouput' is not defined

# %%
# your_list = ['item1', 'item2', 'item3',...]
# df = DataFrame (your_list,columns=['Column_Name'])

# %%
# Build query URL
# query_url = base_url + "api_key=" + api_key + "&winename=" + wine + "&vintage=" + vintage

# %%
# Alternate syntax, using params dictionary

        # parameters = {
        #     'api_key': api_key,
        #     'winename': wine_name,
        #     'vintage': vintage_year,
        #     'format': format_,
        #     'location': location
        # }

# %%
# Get wine data
    # wine_response = requests.get(url=base_url, params=parameters)
    # wine_response
# Out:
# <Response [200]>

# %%
wine_response_json = wine_response.json()
wine_response_json
# Out:
# {'return-code': 0,
#  'list-comment': 'Marketplace',
#  'list-location': 'USA',
#  'list-state': '',
#  'list-currency-code': 'USD',
#  'list-count': 18,
#  'prices-and-stores': [{'merchant-name': 'Glendale Liquor',
#    'merchant-description': 'Liquor store, sells wine and spirits. ex. sales tax',
#    'physical-address': '1311 E Colorado St, Glendale, CA 91205',
#    'zip-code': '91205',
#    'latitude': 34.142875,
#    'longitude': -118.237198,
#    'country': 'USA',
#    'state': 'CA',
#    'vintage': 2016,
#    'price': '45.99',
#    'bottle-size': 'Bottle (750ml)',
#    'link': 'https://www.wine-searcher.com/redirect?from_type_F=A&from_page_F=1462&wine_id_F=4114963&wine_name_id_F=85261&merchant_id_F=134445&price_F=33.497078&page_no_F=1&line_no_F=1&ebp_price_F=33.497078&bot_size_F=Bottle+%28750ml%29&design_F=&offer_type_F=R&tax_status_F=ex.+sales+tax&Xwinename=duckhorn%2Bvineyards%2Bnapa%2Bmerlot&Xvintage_F=2016&Xlocation=USA&Xcurrencycode=USD'},
# ...

# %%
import pandas as pd
import csv
import pathlib
import psycopg2

from sqlalchemy import create_engine

# %%
df = pd.read_csv('new_clean_csv/transformed_data_clean_v1.csv', index_col=0)

# Show dataframe
print(df)
# Out:
#               merchant-name  \
# ID
# 0                      B-21
# 1    Saratoga Wine Exchange
# 2      Hi-Time Wine Cellars
# 3      Woods Wholesale Wine
# 4        K&L Wine Merchants
# ..                      ...
# 126   Pop's Wines & Spirits
# 127  Wally's Wine & Spirits
# 128  Chap4 Fine+Rare Supply
# 129  Chap4 Fine+Rare Supply
# 130                    Punt
#
#                                   merchant-description  \
# ID
# 0     Wine merchant established in 1948. ex. sales tax
# 1    Retail wine store located in upstate New York....
# 2    Retail wine, beer and spirits shop specializin...
# 3    Michigan's #1 Wine & Spirits Retailer. ex. sal...
# 4     Wine merchant established in 1976. ex. sales tax
# ..                                                 ...
# 126        New York based wine merchant. ex. sales tax
# 127                Online wine merchant. ex. sales tax
# 128  Fine and Rare Wine retailer with 25 years expe...
# ...

# %%
df['Criteria'] = 'duckhorn_vineyard_napa_merlot'
df
# Out:
#               merchant-name  \
# ID
# 0                      B-21
# 1    Saratoga Wine Exchange
# 2      Hi-Time Wine Cellars
# 3      Woods Wholesale Wine
# 4        K&L Wine Merchants
# ..                      ...
# 126   Pop's Wines & Spirits
# 127  Wally's Wine & Spirits
# 128  Chap4 Fine+Rare Supply
# 129  Chap4 Fine+Rare Supply
# 130                    Punt
#
#                                   merchant-description  \
# ID
# 0     Wine merchant established in 1948. ex. sales tax
# 1    Retail wine store located in upstate New York....
# 2    Retail wine, beer and spirits shop specializin...
# 3    Michigan's #1 Wine & Spirits Retailer. ex. sal...
# 4     Wine merchant established in 1976. ex. sales tax
# ..                                                 ...
# 126        New York based wine merchant. ex. sales tax
# 127                Online wine merchant. ex. sales tax
# 128  Fine and Rare Wine retailer with 25 years expe...
# ...

# %%
engine = create_engine('postgresql://postgres:password@localhost:5432/WineETL')
df.to_sql('ws_duckhorn_vineyard_napa_merlot', engine)

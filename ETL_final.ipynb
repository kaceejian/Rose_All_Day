# %%
import pandas as pd 
import requests
import json
import pathlib
import csv
import psycopg2

from sqlalchemy import create_engine

# %%
target_wine = "duckhorn+vineyard+napa+merlot"
vintages = [2018, 2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1997,1996,1995,1994,1992,1990,1989,1988,1987,1986,1985,1982,1979]

# %%
output =[]

for vintage in vintages:
    results=requests.get(f'https://api.wine-searcher.com/a?api_key=sctdsly08902219021&winename={target_wine}&vintage={vintage}&format=j&location=USA').json()
    
    output.append(results)

# %%
output[0]['prices-and-stores'][0]
# Out:
# {'merchant-name': 'B-21',
#  'merchant-description': 'Wine merchant established in 1948. ex. sales tax',
#  'physical-address': '43380 US Highway 19 North, Tarpon Springs, FL 34689',
#  'zip-code': '34689',
#  'latitude': 28.165844,
#  'longitude': -82.74105,
#  'country': 'USA',
#  'state': 'FL',
#  'vintage': 2018,
#  'price': '19.98',
#  'bottle-size': 'Half Bottle (375ml)',
#  'link': 'https://www.wine-searcher.com/redirect?from_type_F=A&from_page_F=1462&wine_id_F=4115521&wine_name_id_F=85261&merchant_id_F=34&price_F=14.629113&page_no_F=1&line_no_F=1&ebp_price_F=29.258226&bot_size_F=Half+Bottle+%28375ml%29&design_F=&offer_type_F=R&tax_status_F=ex.+sales+tax&Xwinename=duckhorn+vineyard+napa+merlot&Xvintage_F=2018&Xlocation=USA&Xcurrencycode=USD'}

# %%
dataset = []
for i in range(len(output)):
     for j in range(len(output[i]['prices-and-stores'])):
          row = output[i]['prices-and-stores'][j]
          dataset.append(row)

# %%
df=pd.DataFrame(dataset)
df['Criteria'] = target_wine
df
# Out:
#               merchant-name  \
# 0                      B-21
# 1    Saratoga Wine Exchange
# 2      Woods Wholesale Wine
# 3        K&L Wine Merchants
# 4                Wine House
# ..                      ...
# 127   Pop's Wines & Spirits
# 128  Wally's Wine & Spirits
# 129  Chap4 Fine+Rare Supply
# 130  Chap4 Fine+Rare Supply
# 131                    Punt
#
#                                   merchant-description  \
# 0     Wine merchant established in 1948. ex. sales tax
# 1    Retail wine store located in upstate New York....
# 2    Michigan's #1 Wine & Spirits Retailer. ex. sal...
# 3     Wine merchant established in 1976. ex. sales tax
# 4    Wine retailer serving customers from around th...
# ..                                                 ...
# 127        New York based wine merchant. ex. sales tax
# 128                Online wine merchant. ex. sales tax
# 129  Fine and Rare Wine retailer with 25 years expe...
# 130  Fine and Rare Wine retailer with 25 years expe...
# 131  Retailer specializing in small production, hig...
#
#                                       physical-address zip-code   latitude  \
# 0    43380 US Highway 19 North, Tarpon Springs, FL ...    34689  28.165844
# 1          43 Round Lake Road, Ballston Lake, NY 12019    12019  42.934360
# 2     20787 Mack Avenue, Grosse Pointe Woods, MI 48236    48236  42.445356
# 3          3005 El Camino Real, Redwood City, CA 94061    94061  37.468422
# 4            2311 Cotner Avenue, Los Angeles, CA 90064    90064  34.037552
# ..                                                 ...      ...        ...
# 127         256 Long Beach Road, Island Park, NY 11558    11558  40.603841
# 128  10459 Jefferson Blvd. Culver City, Los Angeles...    90232  34.007060
# 129              9520 Jefferson Blvd. Culver, CA 90232    90232  34.018210
# 130              9520 Jefferson Blvd. Culver, CA 90232    90232  34.018210
# 131  Suite 1, 60 Liberty Ship Way, Sausalito, CA 94965    94965  37.862835
#
#       longitude country state  vintage   price          bottle-size  \
# 0    -82.741050     USA    FL     2018   19.98  Half Bottle (375ml)
# 1    -73.812305     USA    NY     2018   23.94  Half Bottle (375ml)
# 2    -82.906895     USA    MI     2018   24.94  Half Bottle (375ml)
# 3   -122.210258     USA    CA     2018   24.95  Half Bottle (375ml)
# 4   -118.438123     USA    CA     2018   24.99  Half Bottle (375ml)
# ..          ...     ...   ...      ...     ...                  ...
# 127  -73.655997     USA    NY     1986  129.99       Bottle (750ml)
# 128 -118.392573     USA    CA     1985   75.00       Bottle (750ml)
# 129 -118.386511     USA    CA     1982   60.00       Bottle (750ml)
# 130 -118.386511     USA    CA     1982   75.00       Bottle (750ml)
# 131 -122.491883     USA    CA     1979  350.00       Bottle (750ml)
#
#                                                   link  \
# 0    https://www.wine-searcher.com/redirect?from_ty...
# 1    https://www.wine-searcher.com/redirect?from_ty...
# 2    https://www.wine-searcher.com/redirect?from_ty...
# 3    https://www.wine-searcher.com/redirect?from_ty...
# 4    https://www.wine-searcher.com/redirect?from_ty...
# ..                                                 ...
# 127  https://www.wine-searcher.com/redirect?from_ty...
# 128  https://www.wine-searcher.com/redirect?from_ty...
# 129  https://www.wine-searcher.com/redirect?from_ty...
# 130  https://www.wine-searcher.com/redirect?from_ty...
# 131  https://www.wine-searcher.com/redirect?from_ty...
#
#                           Criteria
# 0    duckhorn+vineyard+napa+merlot
# 1    duckhorn+vineyard+napa+merlot
# 2    duckhorn+vineyard+napa+merlot
# 3    duckhorn+vineyard+napa+merlot
# 4    duckhorn+vineyard+napa+merlot
# ..                             ...
# 127  duckhorn+vineyard+napa+merlot
# 128  duckhorn+vineyard+napa+merlot
# 129  duckhorn+vineyard+napa+merlot
# 130  duckhorn+vineyard+napa+merlot
# 131  duckhorn+vineyard+napa+merlot
#
# [132 rows x 13 columns]

# %%
engine = create_engine('postgresql://postgres:password@localhost:5432/WineETL')
df.to_sql('wine_search2', engine)

# %%
df.to_csv('data5.csv')
